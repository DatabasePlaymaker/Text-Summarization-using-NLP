# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
text = """
There are many techniques available to generate extractive summarization to 
keep it simple, I will be using an unsupervised learning approach to find the 
sentences similarity and rank them. Summarization can be defined as a task of 
producing a concise and fluent summary while preserving key information and 
overall meaning. One benefit of this will be, you don’t need to train and 
build a model prior start using it for your project. It’s good to understand 
Cosine similarity to make the best use of the code you are going to see. 
Cosine similarity is a measure of similarity between two non-zero vectors of 
an inner product space that measures the cosine of the angle between them. 
Its measures cosine of the angle between vectors. The angle will be 0 if 
sentences are similar.
"""

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
tokens = [token.text for token in doc]
print(tokens)

# %%
 punctuation = punctuation + '\n'
 punctuation

# %%
word_frequencies = {}
for word in doc:
  if word.text.lower() not in stopwords:
    if word.text.lower() not in punctuation:
      if word.text not in word_frequencies.keys():
        word_frequencies[word.text] = 1
      else:
        word_frequencies[word.text] += 1

# %%
word_frequencies
# Out:
# {'0': 1,
#  'Cosine': 2,
#  'Summarization': 1,
#  'angle': 3,
#  'approach': 1,
#  'available': 1,
#  'benefit': 1,
#  'best': 1,
#  'build': 1,
#  'code': 1,
#  'concise': 1,
#  'cosine': 2,
#  'defined': 1,
#  'extractive': 1,
#  'find': 1,
#  'fluent': 1,
#  'generate': 1,
#  'going': 1,
#  'good': 1,
#  'information': 1,
#  'inner': 1,
#  'key': 1,
#  'learning': 1,
#  'meaning': 1,
#  'measure': 1,
#  'measures': 2,
#  'model': 1,
#  'need': 1,
#  'non': 1,
#  'overall': 1,
#  'preserving': 1,
#  'prior': 1,
#  'producing': 1,
#  'product': 1,
#  'project': 1,
#  'rank': 1,
#  'sentences': 2,
#  'similar': 1,
#  'similarity': 4,
#  'simple': 1,
#  'space': 1,
#  'start': 1,
#  'summarization': 1,
#  'summary': 1,
#  'task': 1,
#  'techniques': 1,
#  'train': 1,
#  'understand': 1,
#  'unsupervised': 1,
#  'use': 1,
#  'vectors': 2,
#  'zero': 1}

# %%
max_frecuency = max(word_frequencies.values())

# %%
max_frecuency
# Out:
# 4

# %%
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frecuency

# %%
print(word_frequencies)
# Out:
# {'techniques': 0.25, 'available': 0.25, 'generate': 0.25, 'extractive': 0.25, 'summarization': 0.25, 'simple': 0.25, 'unsupervised': 0.25, 'learning': 0.25, 'approach': 0.25, 'find': 0.25, 'sentences': 0.5, 'similarity': 1.0, 'rank': 0.25, 'Summarization': 0.25, 'defined': 0.25, 'task': 0.25, 'producing': 0.25, 'concise': 0.25, 'fluent': 0.25, 'summary': 0.25, 'preserving': 0.25, 'key': 0.25, 'information': 0.25, 'overall': 0.25, 'meaning': 0.25, 'benefit': 0.25, 'need': 0.25, 'train': 0.25, 'build': 0.25, 'model': 0.25, 'prior': 0.25, 'start': 0.25, 'project': 0.25, 'good': 0.25, 'understand': 0.25, 'Cosine': 0.5, 'best': 0.25, 'use': 0.25, 'code': 0.25, 'going': 0.25, 'measure': 0.25, 'non': 0.25, 'zero': 0.25, 'vectors': 0.5, 'inner': 0.25, 'product': 0.25, 'space': 0.25, 'measures': 0.5, 'cosine': 0.5, 'angle': 0.75, '0': 0.25, 'similar': 0.25}

# %%
sentence_tokens = [sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [
# There are many techniques available to generate extractive summarization to
# keep it simple, I will be using an unsupervised learning approach to find the
# sentences similarity and rank them., Summarization can be defined as a task of
# producing a concise and fluent summary while preserving key information and
# overall meaning., One benefit of this will be, you don’t need to train and
# build a model prior start using it for your project., It’s good to understand
# Cosine similarity to make the best use of the code you are going to see.
# , Cosine similarity is a measure of similarity between two non-zero vectors of
# an inner product space that measures the cosine of the angle between them.
# , Its measures cosine of the angle between vectors., The angle will be 0 if
# sentences are similar.
# ]

# %%
sentence_score = {}
for sent in sentence_tokens:
    for word in sent:
      if word.text.lower() in word_frequencies.keys():
        if sent  not in sentence_score.keys():
            sentence_score[sent] = word_frequencies[word.text.lower()]
        else:
            sentence_score[sent] += word_frequencies[word.text.lower()]

# %%
sentence_score
# Out:
# {
#  There are many techniques available to generate extractive summarization to
#  keep it simple, I will be using an unsupervised learning approach to find the
#  sentences similarity and rank them.: 4.25,
#  Summarization can be defined as a task of
#  producing a concise and fluent summary while preserving key information and
#  overall meaning.: 3.0,
#  One benefit of this will be, you don’t need to train and
#  build a model prior start using it for your project.: 2.0,
#  It’s good to understand
#  Cosine similarity to make the best use of the code you are going to see. : 3.0,
#  Cosine similarity is a measure of similarity between two non-zero vectors of
#  an inner product space that measures the cosine of the angle between them. : 6.25,
#  Its measures cosine of the angle between vectors.: 2.25,
#  The angle will be 0 if
#  sentences are similar.: 1.75}

# %%
from heapq import nlargest

# %%
select_leght = int(len(sentence_tokens)*0.3)
select_leght
# Out:
# 2

# %%
summary = nlargest(select_leght, sentence_score, key = sentence_score.get)

# %%
summary
# Out:
# [Cosine similarity is a measure of similarity between two non-zero vectors of
#  an inner product space that measures the cosine of the angle between them. ,
#  There are many techniques available to generate extractive summarization to
#  keep it simple, I will be using an unsupervised learning approach to find the
#  sentences similarity and rank them.]

# %%
final_summary = [word.text for word in summary]

# %%
summary = ' '.join(final_summary)

# %%
print(text)
# Out:
# There are many techniques available to generate extractive summarization to
# keep it simple, I will be using an unsupervised learning approach to find the
# sentences similarity and rank them. Summarization can be defined as a task of
# producing a concise and fluent summary while preserving key information and
# overall meaning. One benefit of this will be, you don’t need to train and
# build a model prior start using it for your project. It’s good to understand
# Cosine similarity to make the best use of the code you are going to see.
# Cosine similarity is a measure of similarity between two non-zero vectors of
# an inner product space that measures the cosine of the angle between them.
# Its measures cosine of the angle between vectors. The angle will be 0 if
# sentences are similar.

# %%
print(summary)
# Out:
# Cosine similarity is a measure of similarity between two non-zero vectors of
# an inner product space that measures the cosine of the angle between them.
#
# There are many techniques available to generate extractive summarization to
# keep it simple, I will be using an unsupervised learning approach to find the
# sentences similarity and rank them.

# %%
len(text)
# Out:
# 791

# %%
len(summary)
# Out:
# 347
